# %% [markdown]
# <a href="https://colab.research.google.com/github/Behnam9473/AI/blob/main/Yolov8_custom_dataset_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.4/614.4 kB 24.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/input/custom.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=predict \
model=/content/runs/detect/train3/weights/best.pt \
conf=0.25 \
source=/content/drive/MyDrive/c.jpg
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/c.jpg: 640x448 1 AR03-101-01, 1 AR02-101-01, 55.5ms
# Speed: 2.9ms preprocess, 55.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict2
